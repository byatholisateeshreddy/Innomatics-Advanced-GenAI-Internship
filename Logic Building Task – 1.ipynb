# %% [markdown]
# # 1. User Login Check
# ## Problem Statement:
# - Given a username and password, check whether login is successful.
# - username = "admin"
# - password = "1234"
#
# ## Requirements:
# - Print "Login Successful" if both username and password match
# - Otherwise print "Invalid Credentials"
# - Real-World Application: Authentication systems

# %%
username = "admin"
password = "1234"

input_username = input("Enter username:")
input_password = input("Enter password:")

if (username == input_username) and (password == input_password):
    print("Login Successfully")
else:
    print("Invalid Credentials")
# Out:
# Enter username: admin
# Enter password: 1234
# Login Successfully

# %% [markdown]
# # 2. Pass / Fail Analyzer
# ## Problem Statement:
# - Analyze student results.
# - marks = [45, 78, 90, 33, 60]
#
# ## Requirements:
# - A student passes if marks ≥ 50
# - Count the total number of pass students
# - Count the total number of fail students
# - Print the final result clearly
# - Real-World Application: Academic evaluation systems

# %%
marks = [45,78,90,33,60]
pass_count = 0
fail_count = 0

for i in marks:
    if i >= 50:
        pass_count += 1
    else:
        fail_count += 1       
print("total number of passed students",pass_count)
print("total number of failed students",fail_count)
# Out:
# total number of passed students 3
# total number of failed students 2

# %% [markdown]
# # 3. Simple Data Cleaner
# ## Problem Statement:
# - Clean and standardize user names.
# - names = [" Alice ", "bob", " CHARLIE "]
#
# ## Requirements:
# - Remove extra spaces
# - Convert all names to lowercase
# - Print the cleaned list
# - Real-World Application: Data preprocessing before analysis

# %%
names = ["Alice","bob","CHARLIE"]
new_list = [i.strip().lower()for i in names]
print(new_list)
# Out:
# ['alice', 'bob', 'charlie']

# %% [markdown]
# # 4. Message Length Analyzer
# ## Problem Statement:
# - Analyze message sizes.
# - messages = ["Hi", "Welcome to the platform", "OK"]
#
# ## Requirements:
# - Print the length of each message
# - Flag messages longer than 10 characters
# - Real-World Application: Text filtering and validation systems

# %%
messages = ["Hi","Welcome to the platform","OK"]
for i in messages:
    if len(i)>10:
        print(f"{i} length is {len(i)} and it is flaged")
    else:
        print(f"{i} length is {len(i)}")
# Out:
# Hi length is 2
# Welcome to the platform length is 23 and it is flaged
# OK length is 2

# %% [markdown]
# # 5. Error Message Detector
# ## Problem Statement:
# - Detect error messages from system logs.
# - logs = ["INFO", "ERROR", "WARNING", "ERROR"]
#
# ## Requirements:
# - Count the number of "ERROR" entries
# - Print the total error count

# %%
logs = ["INFO", "ERROR", "WARNING", "ERROR"]
count = 0
for i in logs:
    i=i.lower()
    if i=="error":
        count += 1
print("Total error count is :", count)
# Out:
# Total error count is : 2
