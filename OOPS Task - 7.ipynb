# %% [markdown]
# # Problem 1: Smart Light Controller
# ### Problem Statement
# - Create a class to control a smart light that can be turned ON or OFF and display its status.

# %%
class Smart_Light:

    def __int__(self,name):
        self.name = name
        self.status = "OFF"

    def turn_on(self):
        self.status = "ON"
        print(f"{self.name} is {self.status}")

    def turn_off(self):
        self.status = "OFF"
        print(f"{self.name} is {self.status}")

    def display_status(self):
        print(f"{self.name} is {self.ststus}")

bedroom_light = SmartLight("Bedroom Light")

bedroom_light.turn_on()
# Out:
# Bedroom Light is ON.

# %% [markdown]
# # Problem 2: Employee ID Card System
# ### Problem Statement
# - Create a class that stores employee name, ID, and department and displays ID card details.

# %%
class employee:

    def __init__(self,name,ID,department):
        self.name = name
        self.ID = ID
        self.department = department

    def display_details(self):
        print("Employee ID Card")
        print(f"Name: {self.name}")
        print(f"ID: {self.ID}")
        print(f"Department: {self.department}")

emp = employee("Rahul", "EMP102", "IT")

emp.display_details()
# Out:
# Employee ID Card
# Name: Rahul
# ID: EMP102
# Department: IT

# %% [markdown]
# # Problem 3: Mobile Contact Record
# ### Problem Statement
# - Create a class to store contact name and phone number and display contact information.

# %%
class Mobile_contact_record:

    def __init__(self,name,phonenumber):
         self.name = name
         self.phonenumber = phonenumber
   

    def display_contact(self):
        print("Contact Saved")
        print(f"Contact Name: {self.name}")
        print(f"Phone Number: {self.phonenumber}")

contact = Mobile_contact_record("Anita","9876543210")

contact.display_contact()
# Out:
# Contact Saved
# Contact Name: Anita
# Phone Number: 9876543210

# %% [markdown]
# # Problem 4: Product Price Tag Generator
# ### Problem Statement
# - Create a class that stores product name and price and prints a formatted price tag.

# %%
class Product_Price_Generator:

    def __init__(self,productname,price):
        self.productname = productname
        self.price = price
        
    def formatted_price_tag(self):
        print("Formatted price tag")
        print(f"Product Name: {self.productname}")
        print(f"Price: {self.price}")

price_tag = Product_Price_Generator("Headphones","₹2499")

price_tag.formatted_price_tag()
# Out:
# Formatted price tag
# Product Name: Headphones
# Price: ₹2499

# %% [markdown]
# # Problem 5: Movie Rating Display System
# ### Problem Statement
# - Create a class that stores movie name and rating and displays movie details.

# %%
class Movie_Rating:

    def __init__(self,moviename,rating):
        self.moviename = moviename
        self.rating = rating

    def display_movierating(self):
        print(f"Movie Name: {self.moviename}")
        print(f"rating: {self.rating} / 5")

movie = Movie_Rating("Inception","4.8")
movie.display_movierating()
# Out:
# Movie Name: Inception
# rating: 4.8 / 5

# %% [markdown]
# # Problem 6: Delivery Address Manager
# ### Problem Statement
# - Create a class that stores customer name and delivery address and prints delivery details.

# %%
class delivery_address_Manager:

    def __init__(self,customername,address):
         self.customername = customername
         self.address = address
        
    def display_delivery_address(self):
        print("Delivery Details")
        print(f"Customer Name: {self.customername}")
        print(f"Address: {self.address}")

deliveryaddress = delivery_address_Manager("Suman","Hyderabad")

deliveryaddress.display_delivery_address()
# Out:
# Delivery Details
# Customer Name: Suman
# Address: Hyderabad
